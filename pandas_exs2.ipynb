# %% [markdown]
# # Pandas and Seaborn exercises
#
# Before starting, make sure you have numpy, pandas, and seaborn libraries installed (if you work on Google Colab, you don't need to do this):
#
# `pip install numpy`
#
# `pip install pandas`
#
# `pip install seaborn`

# %% [markdown]
# ## 1. Basic scatter plot of a mathematical function in matplotlib
#
# 1. Generate data for $y=x^3$ for $x$ values ranging from -10 to 10. Useful functions: `np.linspace`
# 2. Create a scatter plot in matplotlib to visualize the function. `plt.scatter`
# 3. Customize the plot with the following styles:
# - Set the title of the plot to "Plot of y=x^3".
# - Label the x-axis as "x" and the y-axis as "y".
# - Change the marker color to red.
# - Add gridlines to the plot.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 2. Line plot from data in matplotlib with customization
#
# Load the data from [here](https://raw.githubusercontent.com/robotautas/kursas/master/Pandas/miestai_isvalyti.csv) as before.
# Use your knowledge from the exercise above to recreate the figure below.
#
# 1. Load the CSV file into a pandas DataFrame.
# 2. Select the population data for a specific city (e.g., Vilnius) across all available years.
# 3. Create a line plot to visualize the population trend over the years.
# 4. Customize the plot with the following styles:
# - Set the title of the plot to "Population Trend of Vilnius".
# - Label the x-axis as "Year" and the y-axis as "Population".
# - Change the line color to green and line style to dashed.
# - Add gridlines to the plot.

# %%
# YOUR CODE HERE

# Hint: Select the population data for Vilnius
vilnius_data = df[df['Miestas'] == 'Vilnius'].iloc[0, 1:]

# CONTINUE YOUR CODE HERE

# %% [markdown]
# ## 3. Comparing population growth between 2001 and 2019 in Lithuanian cities
#
# 1. Load the same [CSV file](https://raw.githubusercontent.com/robotautas/kursas/master/Pandas/miestai_isvalyti.csv) into a pandas DataFrame.
# 2. Select the population data for the years 2001 and 2019 for all cities. Cut the dataframe to the first 20 cities.
# 3. (Done for you) Melt the DataFrame to have a long-form DataFrame suitable for Seaborn.
# 4. Create a grouped bar plot to compare the population of cities in 2001 and 2019.
# 5. Customize the plot with the following styles:
# - Set the title of the plot to "Population Comparison of Lithuanian Cities (2001 vs 2019)".
# - Label the x-axis as "City" and the y-axis as "Population".
# - Use different colors for the bars representing 2001 and 2019.
# - Rotate the x-axis labels for better readability.

# %%
# YOUR CODE HERE ...

# Hint: Melt the DataFrame to long-form
population_melted = population_data.melt(id_vars=['Miestas'],
                                         value_vars=['2001', '2019'],
                                         var_name='Year',
                                         value_name='Population')

# CONTINUE YOUR CODE HERE
